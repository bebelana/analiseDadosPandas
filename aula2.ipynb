# %% [markdown]
# <a href="https://colab.research.google.com/github/bebelana/analiseDadosPandas/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Manipulação de dados com o Pandas
#
# Autor: Ana Izabel
#
# Data: 07/02/2023

# %%
# Importando biblioteca pandas do python
import pandas as pd

# %%
# Carregando um conjunto de dados
df = pd.read_excel("/ca-2021-02.xlsx")

# %%
# Exibe os dados do dataFrame
display(df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Exibe a quantidade de linhas e colunas do dataFrame
df.shape
# Out:
# (168409, 16)

# %%
#Exibe as 10 primeiras linhas
display(df.head(10))
# Out:
#   Regiao - Sigla Estado - Sigla        Municipio  \
# 0             NE             AL        ARAPIRACA
# 1             NE             AL        ARAPIRACA
# 2             NE             AL        ARAPIRACA
# 3             NE             AL        ARAPIRACA
# 4             NE             AL        ARAPIRACA
# 5             NE             AL  DELMIRO GOUVEIA
# 6             NE             AL  DELMIRO GOUVEIA
# 7             NE             AL  DELMIRO GOUVEIA
# 8             NE             AL  DELMIRO GOUVEIA
# 9             NE             AL  DELMIRO GOUVEIA
#
#                           Revenda      CNPJ da Revenda           Nome da Rua  \
# 0            POSTO ARAPIRACA LTDA   12.451.076/0004-65        RODOVIA AL 220
# 1            POSTO ARAPIRACA LTDA   12.451.076/0004-65        RODOVIA AL 220
# 2            POSTO ARAPIRACA LTDA   12.451.076/0004-65        RODOVIA AL 220
# 3            POSTO ARAPIRACA LTDA   12.451.076/0004-65        RODOVIA AL 220
# ...

# %%
# Utilizando uma coluna especifica 
revenda = df['Revenda']
display(revenda)
# Out:
# 0                               POSTO ARAPIRACA LTDA
# 1                               POSTO ARAPIRACA LTDA
# 2                               POSTO ARAPIRACA LTDA
# 3                               POSTO ARAPIRACA LTDA
# 4                               POSTO ARAPIRACA LTDA
#                              ...
# 168404    COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168406             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168407             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168408             ABC DISTRIBUICAO DE PETROLEO LTDA
# Name: Revenda, Length: 168409, dtype: object

# %%
# Metodo usado para resumo estatístico da distribuição de cada coluna numerica, 
# incluindo contagem, media, desvio padrão, valor minimo, quartis e valor maximo.
df.describe()
# Out:
#        Valor de Venda  Valor de Compra
# count   168409.000000              0.0
# mean         6.005184              NaN
# std          0.794541              NaN
# min          2.849000              NaN
# 25%          5.339000              NaN
# 50%          5.859000              NaN
# 75%          6.699000              NaN
# max          8.990000              NaN
